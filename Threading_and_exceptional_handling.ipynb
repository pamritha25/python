# %% [markdown]
# <a href="https://colab.research.google.com/github/pamritha25/python/blob/main/Threading_and_exceptional_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **THREADING**
#
# Threading allows multiple parts of a prograrm to run concurrently.
#
# Useful for tasks like:
# Handling multiple user requests.
# Background tsks (eg. monitoring sensors).
# Downloading multiple files simultaneously.

# %% [markdown]
# How to use Threading in Python
#
# 1.Import the threading module.
#
# 2.Create threads using threading.Thread( )
#
# 3.Start threads using ,start( )
#
# 4.Wait for threads to finish using .join( )

# %%
import threading
def task():
  print("thread running")
thread= threading.Thread(target=task)
thread.start()

thread.join()
# Out:
# thread running

# %%
#multiple threads
import threading
def task1():
  print("coding started")
def task2():
  print("code processed")
t1=threading.Thread(target=task1)
t2=threading.Thread(target=task2)
t1.start()
t2.start()
t1.join()
t2.join()
# Out:
# coding started
# code processed

# %%
import threading
def print__numbers():
  for i in range(8):
    print (i)
thread= threading.Thread(target=print__numbers)
thread.start()
thread.join()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
import threading
import time

def download_file(file):
  print(f"Downloading{file}...")
  time.sleep(2)
  print(f"{file}downloaded.")


files=["file1.txt","file2.txt","file3.txt"]
threads=[threading.Thread(target=download_file,args=(f,))for f in files]

for t in threads:
  t.start()

for t in threads:
  t.join()
# Out:
# Sownloadingfile1.txt...
# Sownloadingfile2.txt...
# Sownloadingfile3.txt...
# file1.txtdownloaded.
# file2.txtdownloaded.
# file3.txtdownloaded.

# %% [markdown]
# # Using Threads with Arguments

# %%
import threading
def greet(name):
  print(f"hello,{name}!")
thread=threading.Thread(target=greet, args=("alice",))
thread.start()
thread.join()
# Out:
# hello,alice!

# %% [markdown]
# # Two threading

# %%
import threading
import time
def chef_work():
  for i in range(5):
    print(f"chef:preparing dish{i+1}....")
    time.sleep(2)#simulate time taken to prepare a dish
    if i==2:
      print("chef:calling assistant to wash utensils.")
      time.sleep(1)
      assistant_thread = threading.Thread(target = assistant_work)
      assistant_thread.start()
      assistant_thread.join()
      print("chef:assistant done.resuming dish preparation.")
  print("chef:all dishes are prepared.")

#thread =2(assistant work)
def assistant_work():
  for j in range(3):
    print(f"assistant:washing utensil {j+1}...")
    time.sleep(2)
  print("assistant:all utensils are clean.")
print("kitchen:starting work.")
chef_thread = threading.Thread(target=chef_work)
chef_thread.start()
chef_thread.join()
print("kitchen:all work completed")
# Out:
# kitchen:starting work.
# chef:preparing dish1....
# chef:preparing dish2....
# chef:preparing dish3....
# chef:calling assistant to wash utensils.
# assistant:washing utensil 1...
# assistant:washing utensil 2...
# assistant:washing utensil 3...
# assistant:all utensils are clean.
# chef:assistant done.resuming dish preparation.
# chef:preparing dish4....
# chef:preparing dish5....
# chef:all dishes are prepared.
# kitchen:all work completed

# %% [markdown]
# Write a Python program using threading to simulate music playback and lyrics downloading:
#
# Music playback runs in one thread for 5 seconds, printing a message each second. During the 3rd second, a separate thread starts to simulate downloading lyrics, which takes 3 seconds. Ensure the music playback waits for the lyrics to finish downloading before continuing.
#
# Output
#
# Music Player: Starting music playback. Music Player: Playing music... 1 seconds Music Player: Playing music... 2 seconds Music Player: Playing music... 3 seconds Music Player: Downloading lyrics in the background. Downloading lyrics... 1 seconds Downloading lyrics... 2 seconds Downloading lyrics... 3 seconds Lyrics download completed. Music Player: Lyrics downloaded. Music Player: Playing music... 4 seconds Music Player: Playing music... 5 seconds Music Player: Playback ended

# %%
import threading
import time


def Music_player():

  print(f"Music Player: Start music playback.")
  for i in range(5):
    print(f"Music Player: Playing music {i+1} seconds")
    time.sleep(2)

    if i==2:
      print(f"Music Player: Downloading lyrics in the background.")
      time.sleep(3)
      down_thread= threading.Thread(target=download_lyrics)
      down_thread.start()
      down_thread.join()
  print(f"Music Player: Playback ended")

def download_lyrics():

  for j in range(3):
    print(f"Downloading lyrics... {j+1} seconds.")

music_thread= threading.Thread(target=Music_player)
music_thread.start()
music_thread.join()
print(" download completed.")
# Out:
# Music Player: Start music playback.
# Music Player: Playing music 1 seconds
# Music Player: Playing music 2 seconds
# Music Player: Playing music 3 seconds
# Music Player: Downloading lyrics in the background.
# ...
# Music Player: Playing music 4 seconds
# Music Player: Playing music 5 seconds
# Music Player: Playback ended
#  download completed.

# %% [markdown]
# # **Exceptional handling**

# %% [markdown]
# Exception handling is a programming concept used to manage error or unexpected conditions that occure during the exicution of a programme .it alles the programe to continue running of failgracefully instead of crashing .

# %% [markdown]
# Use Exception Handling?
#
# 1.To prevent the entire program from crashing due to runtime errors.
#
# To provide informative error messages.
#
# To allow recovery or alternative execution paths.

# %% [markdown]
# What are Errors?
# Errors are issues in the code that prevent it from executing successfully.
#
# Types of Errors
#
# 1.Synatx Errors
#
# 2.Runtime Erros
#
# 3.Logical Errors

# %% [markdown]
# # syntax error

# %% [markdown]
# Occur when the code vilates python's syntax rules.
# Detetcted before execution.
# Example: Missing colons, unmatched parentheses.

# %%
if 5>3
   print("this will cause a syntax error")
# Out:
#   File "/tmp/ipython-input-3985338561.py", line 1
#     if 5>3
#           ^
# SyntaxError: expected ':'

# %% [markdown]
# *2. Runtime Errors**
#
#  - Occur during program execution
#  - Example: Division by zero , accessing undefined variable
#
#
#
#
#  Example Code
#  Division by zero :
#
#
#  x=1=/0
#  print(x)

# %%
x=1/0
print(X)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-13447576.py in <cell line: 0>()
# ----> 1 x=1/0
#       2 print(X)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 3. Logical Errors
#
# The program runs but gives incorrect results due to logic flaws,
# Example: incorrect formula or condition.
# incorrect formula for calculating the area of a rectangle
#
# length =5
#
# width= 10
#
# area = length +width # should be length * width
#
# print("Area;",area)
#
# ouput: Area :15
#
# The program runs successsfully but, the result is wrong because of a mustake in the logic of formula
#
#
# [ ]

# %%
try:
  num = int(input("enter a number:"))
  result  =10/num
except ZeroDivisionError:
  print("cannot divided by zero!")
except ValueError:
  Print("please enter a valid number")
else:
  print("Divison successful!Result:", result)
finally:
  print("This block always runs.")
# Out:
# enter a number:5
# Divison successful!Result: 2.0
# This block always runs.

# %%
#logically the concept is error
length  =5
width=10
area=length+width#logically it is  error length*width   is right
print("Area:",area)
# Out:
# Area: 15

# %% [markdown]
# Exeptions are runtime errros that occur during program execution, disrupting the normal flow of a program
#
# **Common Built-in Exceptions:**
#  - ZeroDivisionErrors
#
#  - ValueError
#
#  - KeyError
#
#  - FileNotFoundError
#
#  - indexError

# %%
try:
  x=int(input("enter the number"))
  y=10/x
  print(y)
except ZeroDivisionError:
  print("cannot divided by zero")
# Out:
# enter the number0
# cannot divided by zero

# %%
try:
  x=int(input("enter the number"))
  y=10/x
  print(y)
except ZeroDivisionError as e:
  print(e)
# Out:
# enter the number0
# division by zero

# %%
try:
  print(a) #function is not defined and not creating any variable
except:
  print("error occured")
# Out:
# error occured

# %% [markdown]
# # **If except we do, The error will not show thats the use of the try-exept block**

# %%
print(a)
print("hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3419332936.py in <cell line: 0>()
# ----> 1 print(a)
#       2 print("hello world")
#
# NameError: name 'a' is not defined

# %%
try:
  print(a)
except:
  print("error occured")
print("hello world")
# Out:
# error occured
# hello world

# %% [markdown]
# If except we do, The error will not show thats the use of the try-exept block And it will not stop the code it just skip the error

# %% [markdown]
# # New section
# # **Else and Finally **

# %% [markdown]
#   Runs only if no exceptions occur

# %%
try:
  result =10/2
except ZeroDivisionError:
  print("Error")
else:
  print("Result:",result)
# Out:
# Result: 5.0

# %% [markdown]
# # **Finally Block**

# %%
try:
  file_ = open("data.txt","r")
except FileNotFoundError:
  print("File not found")
finally:
  print("End of a program")
# Out:
# File not found
# End of a program

# %%
import math
print(math.exp(1000))#its overfloerror
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipython-input-1709021166.py in <cell line: 0>()
#       1 import math
# ----> 2 print(math.exp(1000))#its overfloerror
#
# OverflowError: math range error

# %%
obj =43
obj.append()#attribute error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3740143259.py in <cell line: 0>()
#       1 obj =43
# ----> 2 obj.append()#attribute error
#
# AttributeError: 'int' object has no attribute 'append'

# %%
data ={"name":"john"}
print(data["age"])#key error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1624426981.py in <cell line: 0>()
#       1 data ={"name":"john"}
# ----> 2 print(data["age"])#key error
#
# KeyError: 'age'

# %%
my_list =[1,2,3]
print(my_list[5])#index error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3313775734.py in <cell line: 0>()
#       1 my_list =[1,2,3]
# ----> 2 print(my_list[5])#index error
#
# IndexError: list index out of range

# %%
print(int("hello"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-148294692.py in <cell line: 0>()
# ----> 1 print(int("hello"))
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
my_list =[1,2,3]
my_list.remove(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3468833774.py in <cell line: 0>()
#       1 my_list =[1,2,3]
# ----> 2 my_list.remove(5)
#
# ValueError: list.remove(x): x not in list

# %%
print("5"+5) #type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3264514098.py in <cell line: 0>()
# ----> 1 print("5"+5) #type error
#
# TypeError: can only concatenate str (not "int") to str

# %%
open("nonexistnt_file,.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-254438997.py in <cell line: 0>()
# ----> 1 open("nonexistnt_file,.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexistnt_file,.txt'

# %%
try:
  open("nonexistnt_file.txt")
except FileNotFoundError as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'nonexistnt_file.txt'

# %% [markdown]
# # **Raise exception**

# %% [markdown]
# # The raise statement in python is used to manually trigger an exception when a specific error condition occurs.

# %%
age =int(input("enter a number"))
if age<0:
  raise ValueError("age cannot be negative")# definitely an error occured so else condition is not working
else:
  print(f"your age is {"age"}")
print("No try except")
# Out:
# enter a number-1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-222204133.py in <cell line: 0>()
#       1 age =int(input("enter a number"))
#       2 if age<0:
# ----> 3   raise ValueError("age cannot be negative")# definitely an error occured so else condition is not working
#       4 else:
#       5   print(f"your age is {"age"}")
#
# ValueError: age cannot be negative

# %%
try:
  age =int(input("enter a number"))
  if age<0:
        raise ValueError("age cannot be negative")# definitely an error occured so else condition is not working
  else:
    print(f"your age is {"age"}")
except ValueError as e:
  print(e)
print("try except finished")
# Out:
# enter a number-1
# age cannot be negative
# try except finished

# %% [markdown]
# # **custom exceptions**

# %%
class InvalidAgeException(Exception):
  "Raised when the input value is less than 18"
  pass

# yout need to guess this number
number=18
try:
  input_num = int(input("Enter a number: "))
  if input_num < number:
    raise InvalidAgeException

  else:
    print("Eligible to Vote")

except InvalidAgeException:
  print("Exception Occurred : Invalid Age")
# Out:
# Enter a number: 17
# Exception Occurred : Invalid Age

# %% [markdown]
# # **practical questions**

# %% [markdown]
# Write a program that takes two numbers as input and divides the first by the second.
#
# Handle ZeroDivisionError if the second number is zero.

# %%
x=int(input("enter a number"))
y=int(input("enter a number"))
x=x/y
print(z)
# Out:
# enter a number3
# enter a number0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-993348954.py in <cell line: 0>()
#       1 x=int(input("enter a number"))
#       2 y=int(input("enter a number"))
# ----> 3 x=x/y
#       4 print(z)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Ask the user to enter a number.
#
# Handle ValueError if the user enters something that is not a number.

# %%
x=int(input("enter a number"))
if x<0:
  raise ValueError("number cannot be negative")
else:
  print(f"your number is x")
# Out:
# enter a number-1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-38204182.py in <cell line: 0>()
#       1 x=int(input("enter a number"))
#       2 if x<0:
# ----> 3   raise ValueError("number cannot be negative")
#       4 else:
#       5   print(f"your number is x")
#
# ValueError: number cannot be negative

# %% [markdown]
# Create a list of five items.
#
# Ask the user for an index to access an item.
#
# Handle IndexError if the index is out of range.

# %%
my_list=["apple","box","scale","pencil","pen"]
my_list[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3884252717.py in <cell line: 0>()
#       1 my_list=["apple","box","scale","pencil","pen"]
# ----> 2 my_list[6]
#
# IndexError: list index out of range

# %% [markdown]
# Write a program that divides two numbers and handles both ZeroDivisionError and ValueError.

# %%
  x=int(input("enter a number"))
  y=int(input("enter a number"))
  if x<0:
    raise ValueError("x cannot be negative")
  else:
    print("your number is x")
    z=x/y
    print(z)
# Out:
# enter a number4
# enter a number0
# your number is x
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-1438505386.py in <cell line: 0>()
#       5 else:
#       6   print("your number is x")
# ----> 7   z=x/y
#       8   print(z)
#       9
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Demonstrate the use of a try, except, and finally block.
#
# Show that finally runs whether or not an exception occurs.

# %%
try:
  file_ = open("data.txt","r")
except FileNotFoundError:
  print("File not found")
finally:
  print("End of a program")
# Out:
# File not found
# End of a program

# %% [markdown]
# Take a string input from the user and convert it to an integer.
#
# Handle exceptions if the input cannot be converted.

# %%
try:
  x=str(input("enter the number"))
  int(x)
except ValueError:
  print("value is error")
finally:
  print("program completed")
# Out:
# enter the numberhello
# value is error
# program completed

# %% [markdown]
# Custom Exception — Negative Number Error
#
# Create a custom exception called NegativeNumberError.
#
# Raise it when a user enters a negative number.

# %%
class InvalidAgeException(Exception):
  "Raised when the input value is less than 0"
  pass
  number=1
  try:
    input_num=int(input("enter the number"))
    if input_num<number:
      raise InvalidAgeException
    else:
      print("valid number")
  except InvalidAgeException:
    print("Exception occured:Invalid Age")
# Out:
# enter the number-5
# Exception occured:Invalid Age
