# %% [markdown]
# # **Matplotlib**
# **it is used to visualisation of data**

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,"o")
plt.show()

# %%
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import numpy as np
xpoints=np.array([1,2,3,8])
ypoints=np.array([3,6,1,12])
plt.plot(xpoints,ypoints,"o")
plt.show()

# %% [markdown]
# # **DEFAULT X-POINTS**

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([1,2,1,2,1,2])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

ypoints=np.array([3,6,1,12])
plt.plot(ypoints,marker="*")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:b")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:m")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:k")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:c")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,"o:g")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])#ms=markersize
plt.plot(ypoints, marker="o",ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])#ms=markersize
plt.plot(ypoints, marker="o",ms=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])#ms=markersize
plt.plot(ypoints, marker="o",ms=20,mec="r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])#ms=markersize
plt.plot(ypoints, marker="o",ms=20,mec="k")#mec=markercolour
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])#ms=markersize#mfc=markerface colour
plt.plot(ypoints, marker="o",ms=20,mec="r",mfc="r")
plt.show()

# %% [markdown]
# # **Matplotlib line**

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linestyle="dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linestyle="dashed")
plt.show()

# %% [markdown]
# **shorten syntax**

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,color="r")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,color="k")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth="20.5")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,linewidth="15")
plt.show()

# %% [markdown]
# # **MULTIPLE LINES**

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([1,10,6,9])
y2=np.array([8,3,7,12])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=([1,17,3,4])
y1=([5,6,5,8])
x2=([9,10,11,12])
y2=([132,14,15,16])
plt.plot(x1)
plt.plot(y1)
plt.plot(x2)
plt.plot(y2)
plt.show()

# %% [markdown]
# # **MATPLOTLIB LABELS AND TITLE**

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330]) # Adjusted y to have 9 elements
plt.plot(x,y)
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %% [markdown]
# # **set title**

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330]) # Adjusted y to have 9 elements
plt.plot(x,y)
plt.title("sports match Data")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %% [markdown]
# **set font properties for title and labels**

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={"family":"series","color":"blue","size":20}
font2={"family":"series","color":"darkred","size":15}

plt.plot(x,y)
plt.title("sports watch data",fontdict=font1)
plt.xlabel("Average pulse",fontdict= font2)
plt.ylabel("Calorie burnage",fontdict=font2)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'series' not found.

# %% [markdown]
# # **position the title**

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={"family":"series","color":"blue","size":20}
font2={"family":"series","color":"darkred","size":15}

plt.plot(x,y)
plt.title("sports watch data",loc="left")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={"family":"series","color":"blue","size":20}
font2={"family":"series","color":"darkred","size":15}

plt.plot(x,y)
plt.title("sports watch data",loc="right")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %% [markdown]
# # **Matplotlib adding grid lines**

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={"family":"series","color":"blue","size":20}
font2={"family":"series","color":"darkred","size":15}

plt.plot(x,y)
plt.title("sports watch data",loc="right")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %%
from matplotlib.lines import lineStyles
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={"family":"series","color":"blue","size":20}
font2={"family":"series","color":"darkred","size":15}

plt.plot(x,y)
plt.grid(color="green",linestyle="-",linewidth=0.5)
plt.title("sports watch data",loc="right")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,98,95,100,105,110,115,128,125])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={"family":"series","color":"blue","size":20}
font2={"family":"series","color":"darkred","size":15}

plt.plot(x,y)
plt.grid(axis="x")
plt.title("sports watch data",loc="right")
plt.xlabel("Average pulse")
plt.ylabel("Calorie burnage")
plt.show()

# %% [markdown]
# # **Matplotlib subplots**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)#last one means it will be shown at first phase
plt.plot(x,y)

# %%
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)#it will be shown at 2nd phase(2nd plot)
# 1 row,2 column,second plot
plt.plot(x,y)
plt.show()

# %% [markdown]
# # **The subplots () function**
#
# **The subplots  function takes three arguments that describes the layout of the figure**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3,])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,4)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,6)
plt.plot(x,y)

# %% [markdown]
# # **TITLE**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("SALES")
# Out:
# Text(0.5, 1.0, 'SALES')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("INCOME")
# Out:
# Text(0.5, 1.0, 'INCOME')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("SALES")
# Out:
# Text(0.5, 1.0, 'SALES')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("my shop")
# Out:
# Text(0.5, 0.98, 'my shop')

# %% [markdown]
# # **MATPLOTLIB SCATTER**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # **compare plots**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([112,98,91,92,118,76,83,77,94,78,77,81,56])
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # **COLORS**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x,y,color="hotpink")

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([112,98,91,92,118,76,83,77,94,78,77,81,56])

plt.scatter(x,y,color="green")
plt.show()

# %% [markdown]
# # **COLOUR EACH DOT**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors=np.array(["red","green","blue","yellow","pink","black","orange","purple","orange","purple","beige","brown","gray"])

plt.scatter(x,y,c=colors)
plt.show()

# %% [markdown]
# # **#colour code =viridis**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,c=colors,cmap="viridis")
plt.colorbar()
plt.show()
# Out:
# /tmp/ipython-input-2867298187.py:5: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x,y,c=colors,cmap="viridis")

# %% [markdown]
# # **SIZE**

# %%
from matplotlib import colorbar
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes=np.array([20,50,100,200,500,1000,60,90,300,600,800,75,100]) # Added one element to match the length of x and y
plt.scatter(x,y,s=sizes)

plt.show()

# %% [markdown]
# # **Alpha**
#
# **reduce colour grading**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y,s=sizes,alpha=0.5)
plt.show()

# %% [markdown]
# # **Combine colour size and alpha**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randint(100,size=(100))
y = np.random.randint(100,size=(100))
colors = np.random.randint(100,size=(100))
sizes = 10*np.random.randint(100,size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap="nipy_spectral")
plt.colorbar()
plt.show()

# %% [markdown]
# # **MATPLOTLIB BARS**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["apples","bananas"]
y=[550,300]
plt.bar(x,y)
plt.show()

# %% [markdown]
# # **HORIZONTAL BARS**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y)
plt.show()

# %% [markdown]
# # **BAR COLOR**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,color="red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y,color="hotpink")
plt.show()

# %% [markdown]
# # **BARWIDTH**

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,height=0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y,height=0.5)
plt.show()

# %% [markdown]
# ## **MATPLOTLIB HISTOGRAMS**

# %%
import numpy as np
x=np.random.normal(170,10,250)
print(x)
# Out:
# [169.08713672 151.03382667 172.58190098 177.86513997 176.62391323
#  177.36119763 174.71224669 169.9875611  164.77084    180.01124581
#  173.72913799 183.03482212 171.50737194 176.12638058 166.93036414
#  168.4480557  180.3898957  177.88831666 168.39053146 174.52568375
#  179.01361467 158.93212672 182.59841076 165.7899158  169.82727231
#  171.12273447 179.08657099 178.48663053 162.91466007 173.8208508
#  167.73438705 162.25181116 157.90054705 181.70591309 164.35953465
#  170.84606795 180.58289037 167.3698163  179.74546318 175.4972111
#  159.54498635 175.14000579 174.93494252 184.32510871 166.61551085
#  184.24263651 156.68012348 180.76736693 178.04670028 167.97689672
#  162.14715383 184.1139449  170.92996357 168.42081075 153.99412817
#  163.64851116 160.16044375 177.88040109 161.21258779 182.36728603
#  172.33684794 168.87265822 166.64408603 180.90144388 173.44532102
#  160.72865545 176.44915369 163.79629228 161.65560693 162.20445456
# ...

# %%
import numpy as np
x=np.random.normal(170,10,250)
plt.hist(x)
plt.show()

# %% [markdown]
# # **MATPLOTLIB PIE CHARTS**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
plt.pie(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([12,35,8,45])
plt.pie(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **LABELS**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
plt.pie(y,labels=mylabels)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **START ANGLE**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
plt.pie(y,labels=mylabels,startangle=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
plt.pie(y,labels=mylabels,startangle=75)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **EXPLODE**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
myexplode=[0.2,0,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
myexplode=[0,0.2,0,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
myexplode=[0,0,0.2,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
myexplode=[0,0,0,0.2]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **SHADOW**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
myexplode=[0,0,0.2,0]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # **COLORS**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
mycolors=["green","red","hotpink","black"]

plt.pie(y,labels=mylabels,colors=mycolors)
plt.show()

# %% [markdown]
# # **LEGEND**

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]
plt.pie(y,labels=mylabels)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,25,25,15])
mylabels=["Apples","bananas","cherries","Dates"]

plt.pie(y,labels=mylabels)
plt.legend(title="four fruits")
plt.show()

# %% [markdown]
# # **WAFFLE CHART**

# %%
# !pip install pywaffle
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.6/25.6 MB 53.7 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from pywaffle import Waffle
fig=plt.figure(
    FigureClass=Waffle,
    rows=5,
    columns=10,
    values=[48,46,6],
    figsize=(5,3)
)
plt.show()
# Out:
# <Waffle size 500x300 with 1 Axes>

# %%
data={"democratic":48,"Republican":46,"Libertian":3}
fig=plt.figure(
     FigureClass=Waffle,
     rows=5,
     values=data,
     legend={"loc":"upper left","bbox_to_anchor":(1.1,1)}

)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
data={"democratic":48,"Republican":46,"Libertian":3}
fig=plt.figure(
     FigureClass=Waffle,
     rows=5,
     values=data,
     colors=["brown","purple","hotpink"],
     legend={"loc":"upper left","bbox_to_anchor":(1.1,1)},
     starting_location="NW",
     block_arranging_style="snake"

)
fig.suptitle("vote percentage in 2016 us presidential election")
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
data={"democratic":48,"Republican":46,"Libertian":3}
fig=plt.figure(
     FigureClass=Waffle,
     rows=5,
     values=data,
     colors=["brown","purple","hotpink"],
     legend={"loc":"upper left","bbox_to_anchor":(1,1)},
     icons="child",

     font_size=12,
     icon_legend=True

)

plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text="""oh oh oh oh  oh verse wrote book stand title book would life superman thats make feel count
      privilege love ideal honored know feel see everyday things things say rock baby truth rock love
      rock rock everything need rock baby rock wanna kiss ya feel ya please ya right wanna touch ya
      love ya baby night"""
# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0).generate(text)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
