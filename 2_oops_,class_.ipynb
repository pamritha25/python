# %% [markdown]
# <a href="https://colab.research.google.com/github/pamritha25/python/blob/main/2_oops_%2Cclass_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # class and object

# %%
class phone :
  def make_call(self):
    print("let us make a phone call")
  def play_game(self):
    print("let us play a game")
p1=phone()
p1.make_call()
p1.play_game()
# Out:
# let us make a phone call
# let us play a game

# %%
class phone :
  def make_call(self):
    print("let us make a phone call")
  def play_game(self):
    print("let us play a game")

  def set_color(self,color):  #adding new paramters and  creating new function
    self.color =color

  def set_cost(self,cost):
    self.cost =cost

  def show_color(self):
    return self.color

  def show_cost(self):
    return self.cost

p2=phone()        #making another object
p2.set_color("blue")
p2.show_color()
# Out:
# 'blue'

# %%
p2.set_cost(2500)
p2.show_cost()
# Out:
# 2500

# %% [markdown]
# # creating class with comstructor

# %%
class employee:
  def __init__(self,name,age,salary,gender):   #init method is constructor
    self.name=name
    self.age =age
    self.salary=salary
    self.gender=gender
  def employee_details(self):
    print("Name of employee is ",self.name)
    print("Age of employee is ",self.age)
    print("Salary of employee is ",self.salary)
    print("Gender of employee is ",self.gender)


e1=employee("dohn",34,145000,"male")
e1.employee_details()
# Out:
# Name of employee is  dohn
# Age of employee is  34
# Salary of employee is  145000
# Gender of employee is  male

# %%
class character:
  def __init__(self,health,damage,power):
    self.health=health
    self.damage=damage
    self.power=power
ninja= character(100,30,90)
warrior=character(200,40,95)
print("power of ninja:",ninja.power)
print("power of ninja:",ninja.health)
print("power of ninja:",ninja.damage)
print("power of ninja:",warrior.damage)
print("power of ninja:",warrior.power)
print("power of ninja:",warrior.health)
# Out:
# power of ninja: 90
# power of ninja: 100
# power of ninja: 30
# power of ninja: 40
# power of ninja: 95
# power of ninja: 200

# %%
class character:

  def __init__(self,health,damage,power):
    self.health = health
    self.damage = damage
    self.power = power

  def double(self):
    self.power=self.power*2
    self.damage=self.damage*3
ninja = character(100,30,90)
warrior = character(200,30,95)
print("Power of ninja: ",ninja.power)
print("Power of ninja: ",ninja.health)
ninja.double()
print("After doubling the power")
print("power of ninja: ",ninja.power)
print("damage of ninja:",ninja.damage)
# Out:
# Power of ninja:  90
# Power of ninja:  100
# After doubling the power
# power of ninja:  180
# damage of ninja: 90

# %%
class character:

  def __init__(self,name,health,damage,power):
    self.name=name
    self.health = health
    self.damage = damage
    self.power = power

  def hai(self):
    print("Hello I am ",self.name)

  def is_alive(self):
    if self.health <=0:
      print(self.name,"is Dead!")
    else:
      print(self.name,"is alive!")


  def player_details(self):
    print("....."*5)
    print("Name of player is :",self.name)
    print("Health of player is :",self.health)
    print("damage of player is :",self.damage)
    print("power of player is :",self.power)
    print()
ninja = character("Ninja",100,30,90)
warrior = character("Warrior",200,40,95)


ninja.hai()
ninja.health=0
print("Health of ninja:",ninja.health)
ninja.is_alive()
warrior.is_alive()

warrior.player_details()
ninja.player_details()
# Out:
# Hello I am  Ninja
# Health of ninja: 0
# Ninja is Dead!
# Warrior is alive!
# .........................
# Name of player is : Warrior
# Health of player is : 200
# damage of player is : 40
# power of player is : 95
#
# .........................
# Name of player is : Ninja
# Health of player is : 0
# damage of player is : 30
# power of player is : 90

# %%
class character:
  def __init__(self,name,gender,marks):
    self.name=name
    self.gender=gender
    self.marks=marks

  def student_details(self):
    print("name of student is:",self.name)
    print("gender of the student is:",self.gender)
    print("marks of the student is:",self.marks)

p2=character("sriya","female",78)
p2.student_details()
# Out:
# name of student is: sriya
# gender of the student is: female
# marks of the student is: 78

# %%
class fruits:
  def __init__(self,name,damage):
    self.name=name
    self.damage=damage
  def fruits_details(self):
    print("the name of the fruit is:",self.name)
    print("the damage of the fruit is:",self.damage)
e1=fruits("apple","48 hours")
e2=fruits("banana","24 hours")
e1.fruits_details()
e2.fruits_details()
# Out:
# the name of the fruit is: apple
# the damage of the fruit is: 48 hours
# the name of the fruit is: banana
# the damage of the fruit is: 24 hours

# %%
class student:
  school : "abc school"
  def __init__(self,name,age,roll_number):
    self.name=name
    self.age=age
    self.roll_number=roll_number
  def details(self):
    print("name of the student is:",self.name)
    print("age of the student is:",self.age)
    print("roll number of the student is:",self.roll_number)
student1= student("Anshif",21,3)
student2= student("Sinan",20,7)
print(student1.school)
del student1.name
print(student1.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1607290695.py in <cell line: 0>()
#      11 student1= student("Anshif",21,3)
#      12 student2= student("Sinan",20,7)
# ---> 13 print(student1.school)
#      14 del student1.name
#      15 print(student1.name)
#
# AttributeError: 'student' object has no attribute 'school'

# %%
class student:
  school : "abc school"
  def __init__(self,name,age,roll_number):
    self.name=name
    self.age=age
    self.roll_number=roll_number
  def details(self):
    print("name of the student is:",self.name)
    print("age of the student is:",self.age)
    print("roll number of the student is:",self.roll_number)


student1= student("Anshif",21,3)
student2= student("Sinan",20,7)
print(getattr(student1,"name")) # or print(student1.name)

setattr(student1,"age",23) # or student1.age = 23
print(student1.age)

print(hasattr(student1,"id")) # id attribute checking

delattr(student1,"age") # for delete attribute
# Out:
# Anshif
# 23
# False

# %%
class dog:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def bark(self):
    print(f"{self.name} says: Bow! Bow!")

  def intriduce(self):
    print(f"My name is {self.name} and I am {self.age} years old.")

  def sit(self):
    print(f"{self.name} is now sitting.")

  def fetch(self, item):
    print(f"{self.name} is fetching the {item}!")


dog1=dog("Mubashir",21)
dog2=dog("Jaseem",19)
dog1.bark()
dog2.bark()
dog1.sit()
dog1.intriduce()
dog1.fetch("Alpham mandhi")
dog2.fetch("stick")
# Out:
# Mubashir says: Bow! Bow!
# Jaseem says: Bow! Bow!
# Mubashir is now sitting.
# My name is Mubashir and I am 21 years old.
# Mubashir is fetching the Alpham mandhi!
# Jaseem is fetching the stick!

# %%
class cat:
  def __init__(self,name,colour):
    self.name=name
    self.colour=colour
  def cat_details(self):
    print("f{self.name}and{self.colour}")

  def meow(self):
    print(f"{self.name}says:meow!meow!")
  def purr(self):
    print(f"{self.name}says:purr!purr!")
  def scratch(self,item):
    print(f"{self.name}is scratching on the {item}")
  def sleep(self):
    print(f"{self.name} is sleeping")
e1=cat("miwi","black")
e2=cat("tintu","white")
e1.meow()
e2.purr()
e1.scratch("ball")
e2.sleep()
1.cat
e2.cat_details()e
# Out:
# miwisays:meow!meow!
# tintusays:purr!purr!
# miwiis scratching on the ball
# tintu is sleeping
# f{self.name}and{self.colour}
# f{self.name}and{self.colour}

# %% [markdown]
# # ,Single inheritance:
#  - A derived class inherits form a single parent class, gaining access to its properites and methods

# %%
class animal:#parent class
   def speak (self):
     print("Animal speaking")

class dog(animal):#child class
   def bark(self):
     print("dog barking")
d=dog()
d.bark()
d.speak()
a=animal()
a.bark( )#animal is a parent ,so can not call the childs characters
# Out:
# dog barking
# Animal speaking
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1689387558.py in <cell line: 0>()
#      10 d.speak()
#      11 a=animal()
# ---> 12 a.bark( )#animal is a parent ,so can not call the childs characters
#
# AttributeError: 'animal' object has no attribute 'bark'

# %%
class animal:#parent class
   def speak (self):
     print("Animal speaking")

class dog(animal):#child class
   def bark(self):
     print("dog barking")
d=dog()
d.bark()
d.speak()
a=animal()
a.speak()
# Out:
# dog barking
# Animal speaking
# Animal speaking

# %%
class vehicle:
  def start(self):
    print("vehicle is starting")
  def stop(self):
    print("vehicle is dtopping")
class car(vehicle):
  def drive(self):
    print("the  car is being driven")
my_car=car()
my_car.start()
my_car.drive()
my_car.stop()
# Out:
# vehicle is starting
# the  car is being driven
# vehicle is dtopping

# %%
class competition:
  def start(self):
    print("the competition is starting")

  def stop(self):
    print("the competition is stopping")
  def damage(self):
    print("competition status damaged")

class baloon(competition):
  def inflatted(self):
    print("baloon is inflatted")
d=baloon()
d.start()
d.stop()
d.damage()
# Out:
# the competition is starting
# the competition is stopping
# competition status damaged

# %% [markdown]
# # Multilevel inhertiance
# # A class inherits from another derived class, froming a chain of **inheritance**

# %%
class Animal:
  def speak(self):
    print("Animal speaking")

class Dog(Animal):  # Child class (inheritance)
  def bark(self):
    print("Dog barking")

class Dogchild(Dog):  # multilevel inheritance
  def eat(self):
    print("Eating bread....")

d=Dog()
d.bark()
d.speak()
# d.eat()  AttributeError: 'Dog' object has no attribute 'eat'

print()

d1=Dogchild()  # multilevel child have all method
d1.bark()
d1.speak()
d1.eat()
# Out:
# Dog barking
# Animal speaking
#
# Dog barking
# Animal speaking
# Eating bread....

# %% [markdown]
# # **Hierarchial inheritance:**
# # Multiple derived classes inherit from a single parent class, allowing shared behavior across diggerent subcalsses

# %%
class shape:
  def info(self):
    print("shapes have dimensions")
class circle(shape):
  def circle(self):
    print("circle is drawing")
class rectangle(shape):
  def rectangle(self):
    print("rectangle is drawing")
class square(shape):
  def square(self):
    print("square is drawing")
class hexagon(shape):
  def hexagon(self):
    print("hexagon is drawing")
c=circle()
r=rectangle()
s=square()
h=hexagon()
c.info()
c.circle()
r.info()
r.rectangle()
s.info()
s.square()
h.hexagon()
h.info()
# Out:
# shapes have dimensions
# circle is drawing
# shapes have dimensions
# rectangle is drawing
# shapes have dimensions
# square is drawing
# hexagon is drawing
# shapes have dimensions

# %%
class company:#first generation
  def introduce(self):
    print("iam a company person")
class manager(company):#second generation
  def work(self):
    print("iam working as company manager")
class apprentice(company):#third generation
  def work1(self):
    print("iam working as apprentice")
manager=manager()
apprentice=apprentice()
manager.introduce()
apprentice.work1()
manager.work()
# Out:
# iam a company person
# iam working as apprentice
# iam working as company manager

# %%
class person: # parent
  def introduce(self):
    print("Iam a person..")

class Teacher(person): #child of person
  def teach(self):
    print("I teach students..")

class Student(person): # also child of person
  def study(self):
    print("I study subjects")

teacher=Teacher()
student=Student()

teacher.introduce()
teacher.teach()

print()

student.introduce()
student.study()
# Out:
# Iam a person..
# I teach students..
#
# Iam a person..
# I study subjects

# %% [markdown]
# # Multiple Inheritance:
# # A single derived clas inhertis from multiple parent classes, combining functionalities from different sources.

# %%
class calculation1:
  def summation(self,x,y):
    print(x+y)

class calculation2:
  def multiplication(self,x,y):
    print(x*y)

class derived(calculation1,calculation2):
  def divide(self,x,y):
    print(x/y)
d=derived()
d.summation(10,20)
d.multiplication(10,20)
d.divide(10,20)
# Out:
# 30
# 200
# 0.5

# %% [markdown]
# # Hybrid inheritance
# Hybrid inheritance is a combination of two or more types of inheritance (such as single, multiple, multilevel, or hierarchial inheritance ) in a single program. It allows a more complex class hierarchy to be created, leveraging the benefits of different inheritance types.**bold text** **bold text** **bold text**

# %%
class person:
  def show(self):
    print("I am a person")
class teacher(person):
  def teach(self):
    print("i teach students")

class staff:
  def manage(self):
    print("I manage school activities")

# hybrid inheritenc principal inherits from both teacher and staff (single + multiple)
class principal(teacher, staff):
  def oversea(self):
    print("I oversea the entire school")

principal = principal()
principal.show()
principal.teach()
principal.manage()
principal.oversea()
# Out:
# I am a person
# i teach students
# I manage school activities
# I oversea the entire school

# %% [markdown]
# # practicals inheritence

# %% [markdown]
# Create a Simple Inheritance Structure
# Create a base class Animal with a method make_sound(). Create two child classes Dog and Cat that inherit from Animal and override the make_sound() method to print appropriate sounds.

# %%
class Animal:
  def sound(self):
    print("animal making sound")
class cat(animal):
  def meow(self):
    print("cat makes the sound meowww")
class dog(animal):
  def bow(self):
    print("dog makes the sound bow bow")
c=cat()
d=dog()
Animal()
c.meow()
d.bow()
# Out:
# cat makes the sound meowww
# dog makes the sound bow bow

# %% [markdown]
# Vehicle Inheritance
# Create a class Vehicle with attributes like brand and year. Create a child class Car that adds a model attribute and a method display_details() that prints all attributes.
#
# Use of super()

# %%
class vehicle:
  def __init__(self,brand,year):
    self.brand=brand
    self.year=year

class car(vehicle):
  def model(self,model):
    self.model=model




  def display_details(self):
    print("brand of the car is:",self.brand)
    print("year of the car is:",self.year)
    print("model of the car is:",self.model)

a1=car("mahindra",2024)
a1.model("Thar roxx")

a1.display_details()
# Out:
# brand of the car is: mahindra
# year of the car is: 2024
# model of the car is: Thar roxx

# %%
class fruits:
  def __init__(self,name,damage):
    self.name=name
    self.damage=damage
  def fruits_details(self):
    print("the name of the fruit is:",self.name)
    print("the damage of the fruit is:",self.damage)
e1=fruits("apple","48 hours")
e2=fruits("banana","24 hours")
e1.fruits_details()
e2.fruits_details()

# %% [markdown]
# create a class Student with attributes name and roll_no. Create a subclass Marks that adds marks in three subjects and a method to calculate the total
# # New Section

# %%
class student:
  def __init__(self,name,rollnumber):
    self.name=name
    self.rollnumber=rollnumber
class marks(student):
  def marks(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c

  def display_details(self):
    print("name of the student is:",self.name)
    print("roll number of the student is:",self.rollnumber)
    print("total mark of the sudent is:",self.a+self.b+self.c)
e=marks("abhishek",6)
e.marks(29,32,39)
e.display_details()
# Out:
# name of the student is: abhishek
# roll number of the student is: 6
# total mark of the sudent is: 100

# %% [markdown]
# # Define a class Account with methods for deposit and withdrawal. Create a subclass SavingsAccount that includes an interest rate and a method to add interest.

# %%
class account:
  def __init__(self,balance):
    self.balance=balance
    print("the balance is:",self.balance)
  def deposit(self,deposit):
    self.deposit=deposit
    print("the deposit is:",self.deposit+self.balance)
    self.balance+=deposit
  def withdrawal(self,withdrawal):
    if self.balance<=0:
      print("enter proper amount")
    else:
      self.withdrawal=withdrawal
      print("the balance is:",self.balance-self.withdrawal)


class savings__account(account):
  def interest(self,interest_rate):
    self.interest_rate=interest_rate

    super().__init__(self.balance)
  def add_interest(self):
    interest=self.balance*self.interest_rate
    updated_balance=self.balance+interest

    print("the amount added with interest is:",updated_balance)
a=savings__account(1000)


a.deposit(2000)
a.withdrawal(500)
a.interest(0.2)
a.add_interest()
# Out:
# the balance is: 1000
# the deposit is: 3000
# the balance is: 2500
# the balance is: 3000
# the amount added with interest is: 3600.0

# %% [markdown]
# Polymorphism
# Polymorphism comes from the Greak words "poly" (many) and "morphs" (forms), meaning one task can be performed in different ways. In Object-Oriented programming (oop), polymorphism allows the same method name to behave differently based on the object that calls it.

# %% [markdown]
# Types of Polymorphism
#
# Method Overriding (Runtime Polymorphism)
# A child class provides a specific implemntation of a method that is already defined in the parent class.
# Method Overloading (Compile-time Polymorphism - Not in python):
# Multiple methods with the same name but different parameters. (python does not support method overloading directly like other languages such as java or C++)
# - 1. Method Overriding (Runtime Polymorphism)
# A child class provides a specific implemntation of a method that is already defined in the parent class.
#
# [ ]

# %%
class A:
  def show(self):
    print("Class A")

class B(A):
  def show(self):
    print("Class B")

class C(B):
  def show(self):
    print("Class C")

obj= C()
obj.show() # Method Overriding
# Out:
# Class C

# %%
class A:
  def show(self):
    print("Class A")

class B(A):
  def show(self):
    print("Class B")

class C(B):
  def show(self):
    print("Class C")

obj= B()
obj.show() # Method Overriding
# Out:
# Class B

# %%
class A:
  def show(self):
    print("Class A")

class B(A):
  def show(self):
    print("Class B")

class C(B):
  def show(self):
    print("Class C")

obj= A()
obj.show() # Method Overriding
# Out:
# Class A

# %%
class A:
  def show(self):
    print("Class A")

class B(A):
  def show(self):
    super().show()
    print("Class B")

class C(B):
  def show(self):
    super().show()
    print("Class C")

obj= C()
obj.show()
# Out:
# Class A
# Class B
# Class C

# %%
class A:
  def show(self):
    print("Class A")

class B(A):
  def show(self):
    super().show()
    print("Class B")

class C(B):
  def show(self):
    super().show()
    print("Class C")

obj= B()
obj.show()
# Out:
# Class A
# Class B

# %%
class A:
  def show(self):
    print("Class A")

class B(A):
  def show(self):
    super().show()
    print("Class B")

class C(B):
  def show(self):
    super().show()
    print("Class C")

obj= A()
obj.show()
# Out:
# Class A

# %%
class animal:

  def speak(self):
    print("Animal is making sound")

class dog(animal):
  def speak(self):
    print("Dog barks")

class cat(animal):
  def speak(self):
    print("cat mweows")

dog  = dog()
cat = cat()

dog.speak()
cat.speak()
# Out:
# Dog barks
# cat mweows

# %% [markdown]
# # **Default arguments - Providing default values to parameters.**
#
# [ ]

# %%
class calculator:
  def add(self,a,b=0,c=0):
    print(a+b+c)
calc=calculator()#object creation
calc.add(5)
calc.add(5,10)
calc.add(5,10,15)
# Out:
# 5
# 15
# 30

# %% [markdown]
# # **positional arguments ( args )**

# %%
class mathoperations:
  def add(self,*numbers):
   total=sum(numbers)
   print(f"sum:{total}")
math=mathoperations()
math.add(5,6)
math.add(1,2,3,4,5,6,7,8)
# Out:
# sum:11
# sum:36

# %%
class mathoperations:
  def sub(self,*numbers):

# %% [markdown]
# # **keyword arguments ( keyword )**

# %%
class Greeting:
  def say_hello(self, **kwargs):
    print(f"Hello {kwargs['name']}!")
    print(f"You are {kwargs['age']} years old!")
    print(f"You are from {kwargs['city']}!")

g=Greeting()

g.say_hello(name="Anshif", age=21, city="Puthanathani")
# Out:
# Hello Anshif!
# You are 21 years old!
# You are from Puthanathani!

# %%
class student:
  def student_class(self,**kwargs):
    print(f"iam from{kwargs['group']}!")
    print(f"complementary suject is{kwargs['subject1']}!")
    print(f"eligible for{kwargs['study']}!")
s=student()
s.student_class(group="science",subject1="mathematics",study="higher studies")
# Out:
# iam fromscience!
# complementary suject ismathematics!
# eligible forhigher studies!

# %% [markdown]
# # polymorphism practical

# %% [markdown]
# Create a class Bird with a method move(), and subclasses Penguin and Parrot that redefine move().

# %%
class bird:
  def move(self):
    print("bird is moving on the sky")
class penguin(bird):
  def move(self):
    super().move()
    print("penguin is moving")

class parrot(bird):
  def move(self):
    super().move()
    print("parrot is moving")
obj=parrot()
obj.move()
obj=penguin()
obj.move()#hierarchial inheritance 1 parent and 2 child
# Out:
# bird is moving on the sky
# parrot is moving
# bird is moving on the sky
# penguin is moving

# %% [markdown]
# Implement two unrelated classes Car and Boat, both having a method start_engine().
# Write a function that calls start_engine() for any object passed.

# %%
class car:
  def start_engine(self):
    print("car engine started")
class boat:
  def start_engine(self):
    print(" boat engine is started")
a=boat()
a.start_engine()
b=car()
b.start_engine()
# Out:
#  boat engine is started
# car engine started

# %% [markdown]
# Create a simple function that prints information about different objects like Book, Pen, and Laptop, each implementing a method describe().
#  Demonstrate polymorphism through function calls. **bold text**

# %%
class items:
  def new_items(self):
    print("items is")
class book(items):
  def new_items(self):
    super().new_items()
    print("book")
class pen(items):
  def new_items(self):
    super().new_items()
    print("pen")
class laptop(items):
  def new_items(self):
    super().new_items()
    print("laptop")
a=pen()
a.new_items()
a=laptop()
a.new_items()
a=book()
a.new_items()
# Out:
# items is
# pen
# items is
# laptop
# items is
# book

# %% [markdown]
# Implement a base class Employee with a method calculate_salary().
# Derive subclasses Manager and Developer that override this method differently and demonstrate polymorphism.

# %%
class employee:
  def calculate_salary(self, salary):
    self.salary=salary
    print("the calculated salary is:",self.salary)
class manager(employee):
  def calculate_salary(self,salary):
    print("the  salary of manager")
    super().calculate_salary(salary)

class developer(employee):
  def calculate_salary(self,salary):
    print("salary of developer")
    super().calculate_salary(salary)

x=employee()
x.calculate_salary(200)
y=manager()
y.calculate_salary(500)
z=developer()
z.calculate_salary(400)
# Out:
# the calculated salary is: 200
# the  salary of manager
# the calculated salary is: 500
# salary of developer
# the calculated salary is: 400

# %% [markdown]
# **Encapsulation**
# Encapsulation is one of the fundamental concepts in OOP that refers to binding data ( variables ) and methods ( fucntions ) that operate on the data into a single unit, and restriciting direct access to some of the object's components
#
# In simpler terms, Encapsulation is about protecting data by controlling access to it.

# %% [markdown]
# Key Features of Encapsulation:
# **bold text**
# 1.Data Hiding : Internal detailsof an object aare hidden from the outside world
# 2.Access Controll : Provides controlled access using public, private, and protected access specifiers.
# 3.Improved Security : Prevents unathorized access and accidental modification of data
# Encapsulation Access Specifiers in Python :

# %% [markdown]
# Encapsulation Access Specifiers in Python :
#
# Public Members : Accessible from anywhere.
# Protected Members ( _variable ): Intended for internal use but can be accessed with a warning
# Private Members ( __variables ) : Not accessible directly outside the class
#
# [ ]
# # **New Section**

# %%
class company:
  def __init__(self, company_name,company_id):
    self.__company_name = company_name
    self._company_id = company_id

c1=company("TCS",91)
print(c1._company_id) # we can print one underscore variable
# print(c1.__company_name)    # we can't print two underscore variable !
# Out:
# 91

# %% [markdown]
# # double underscored variable we can't acces outside of class, but we can access on the class

# %%
class company:
  def __init__(self, company_name,company_id):
    self.__company_name = company_name
    self._company_id = company_id

  def get_company_name(self):
    print(self.__company_name)

c1 = company("TCS",91)
c1.get_company_name()
# Out:
# TCS

# %%
class work:
  def __init__(self, worker_name, worker_id):
    self.__worker_name = worker_name
    self.__worker_id  = worker_id
  def get_worker_name(self):
    print(self.__worker_name)
c1 =work("amritha",144)
c1.get_worker_name()
# Out:
# amritha

# %%
class bankaccount:
  def __init__(self, account_number, balance):
    self.__account_number = account_number
    self.__balance = balance
  def deposite(self, amount):
    if amount > 0:
      self.__balance +=amount
      print(f"Deposited {amount}. New balance: {self.__balance}")
    else:
      print("Invalid deposit error")

  def get_balance(self):
    return self.__balance

account = bankaccount("12345", 1000)
account.deposite(500)
# print(account.__balance) AttributeError: 'bankaccount' object has no attribute '_bankaccount__balance'
#print(account.get_balance())
# Out:
# Deposited 500. New balance: 1500

# %% [markdown]
# # abstract

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC): #abstract class

  @abstractmethod
  def start_engine(self):
    pass #abstract method with no implementation


  @abstractmethod
  def stop_engine(self):
    pass #abstract method with no implementation

# An abstract class cannot be instantiated directly
v=Vehicle() # TypeError: Can't instantiate abstract class Vehicle with abstract methods start_engine, stop_engine
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3498563175.py in <cell line: 0>()
#      13
#      14 # An abstract class cannot be instantiated directly
# ---> 15 v=Vehicle() # TypeError: Can't instantiate abstract class Vehicle with abstract methods start_engine, stop_engine
#      16
#
# TypeError: Can't instantiate abstract class Vehicle without an implementation for abstract methods 'start_engine', 'stop_engine'

# %%
from abc import ABC, abstractmethod
class vehicle(ABC):
  @abstractmethod
  def start_engine(self):
    pass
  def stop_engine(self):
    pass
class car(vehicle):
   def start_engine(self):
     print("car engine started")
   def stop_engine(self):
    print("car engine stopped")

car=car()
car.start_engine()
car.start_engine()
# Out:
# car engine started
# car engine started

# %%
from abc import ABC, abstractmethod
class chocolate(ABC):
  @abstractmethod
  def tasting_chocolate(self):
    pass
  def taking_chocolate(self):
    pass
class kitkat(chocolate):
  def tasting_chocolate(self):
    print("kitkat is tasting")
  def taking_chocolate(self):
    print("kitkat is taking")
kitkat= kitkat()
kitkat.tasting_chocolate()
kitkat.taking_chocolate()
# Out:
# kitkat is tasting
# kitkat is taking

# %% [markdown]
# If we want to make object from abstract class we can't directly make object from the abstract class.
#
# So we need to make child class for abstract class object making
#
# And also need to make same method ( function ) on child class also

# %%
from abc import abstractstaticmethod
from abc import ABC, abstractmethod
class shape(ABC):
  @abstractmethod
  def calculate_area(self):
    pass
class circle(shape):
  def __init__(self,radius):
    self.radius=radius
  def calculate_area(self):
    print(f"area of the circle is: {3.14*(self.radius)**2}")

class rectangle(shape):
  def __init__(self,width,height):
    self.width=width
    self.height=height
  def calculate_area(self):
    print(f"area of the rectangle is:{self.height*self.width}")
cir=circle(5)
rect=rectangle(5,10)
cir.calculate_area()
rect.calculate_area()
# Out:
# area of the circle is: 78.5
# area of the rectangle is:50

# %% [markdown]
# class methods
# Class methods can modify class-level variables or properties (variables shared among all instances).This allows changes to be made that affect the class as a whole, rather than just an individual instance.
#
# ( @classmethod ): This is used to define a class method, it indicates that the method is bound to the class, not to an instance.
#
# First Parameter (cls): the first prameter of a class method is always a refernce to the class itself, typically named cls. This is similar to how instance methods have refernce to the instance ( typically names self ).

# %%
class car:
  #clas variable
  wheels = 4

  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  @classmethod
  def change_wheels(cls, new_wheels):
    cls.wheels = new_wheels
    print(f"The number of wheels has been updated to {cls.wheels}.")


# create an instance of car
car1 = car("Toyoata","Etios")

# call the class method to modify the class variable
car.change_wheels(6)

print()

# the class variable "wheels" is now changed for all instances
print(f"car variable updated to :{car1.wheels}")
# Out:
# The number of wheels has been updated to 6.
#
# car variable updated to :6

# %%
class car:
  wheels=4
  def __init__(self,brand):
    self.brand=brand

  def show_brand(self):
    print(f"this car is a {self.brand}")
  @classmethod
  def show_wheels(cls):
    print(f"all cars have {cls.wheels}wheels")

car1=car("toyota")
car2 =car("ford")
car1.show_brand()
car2.show_brand()
car.show_wheels()
car1.show_wheels()
car2.show_wheels()
# Out:
# this car is a toyota
# this car is a ford
# all cars have 4wheels
# all cars have 4wheels
# all cars have 4wheels

# %%
class Car:
    # Class attribute (shared by all instances)
    wheels = 4

    def __init__(self, brand):
        # Instance attribute (unique to each instance)
        self.brand = brand

    def show_brand(self):
        print(f"This car is a {self.brand}")

    @classmethod
    def show_wheels(cls,new_wheel):
      cls.wheels=new_wheel
      print(f"All cars have {cls.wheels} wheels")

# Create instances
car1 = Car("Toyota")
car2 = Car("Ford")

# Instance method: uses 'self' to access instance data
car1.show_brand()  # Output: This car is a Toyota
car2.show_brand()  # Output: This car is a Ford

# Class method: uses 'cls' to access class data
Car.show_wheels(2)

# Can also call class method from an instance (but still accesses class data!)
car1.show_wheels(3)
# Out:
# This car is a Toyota
# This car is a Ford
# All cars have 2 wheels
# All cars have 3 wheels

# %% [markdown]
# # Create an abstract class Employee with abstract methods calculate_salary() and get_details().
# # Then, implement two subclasses:

# %%
from abc import ABC,abstractmethod
class employee(ABC):
  @abstractmethod
  def calculate_salary(self):
    pass


  def get_details(self):
    pass
class employee1(employee):
  def __init__(self,salary):
    self.salary=salary
  def calculate_salary(self):
    print(f"the salary of employee is{self.salary}.")
class employee2(employee):
  def __init(self,name,):
    self.name=name
    print(f"she is{self.name}.")

# %%
from abc import ABC, abstractmethod
class employee(ABC):
  @abstractmethod
  def calculated_salary(self):
    pass
  def get_details(self):
    pass
class employee1(employee):
  def __init__(self,salary,name,company):
    self.salary=salary
    self.name=name
    self.company=company
  def calculated_salary(self):
    print(f"the calculated salary is{self.salary}.")





  def get_details(self):
    print(f"employee is:{self.name} and working on {self.company}")
employee=employee1(34500,"xirin","tata")
employee.calculated_salary()
employee.get_details()
# Out:
# the calculated salary is34500.
# employee is:xirin and working on tata

# %% [markdown]
# **Create an abstract class Polygon with an abstract method number_of_sides(). Implement two subclasses, Triangle and Pentagon, which return the respective number of sides. Instantiate both classes and print the number of sides**.
#
#
# [ ]

# %%
class polygon:
  @abstractmethod
  def number_of_sides():
    pass
class triangle(polygon):
  def __init__(self,sides):
      self.sides=sides
  def number_of_sides(self):
    print(f"the triangle side is {self.sides}.")
class pentagon(polygon):
  def __init__(self,sides):
    self.sides=sides

  def number_of_sides(self):
    print(f"the pentagon side is {self.sides}.")
t=triangle(3)
p=pentagon(5)
t.number_of_sides()

p.number_of_sides()
# Out:
# the triangle side is 3.
# the pentagon side is 5.

# %% [markdown]
# 1. Define a Python class Student with the following private attributes:
#
#   __name to store the student's name.
#   __marks to store the student's marks.
#
# 2. Implement the following public  getter and setter methods to access and modify these attributes securely:
#
# set_name(name) – A method to set the student's name.
# get_name() – A method to retrieve the student's name.
# set_marks(marks) – A method to set the student's marks (Ensure marks cannot be negative).
# get_marks() – A method to retrieve the student's marks.
#
# 3. Demonstrate the usage of the class by:
#
# -Create an instance of the Student class.
# -Setting the name of the student to "Alice" and print it using the getter method.
# -Setting the marks of the student to 95 and print it using the getter method.
# -Dont alow negative marks.

# %%
class student:
   def set_name(self,name):
    self.name=name
   def set_mark(self,mark):
    if mark<0:
      print("marks are not negative")
    else:
      self.mark=mark
   def get_name(self):
    print(self.name)
   def get_mark(self):
    print(self.mark)
a=student()
a.set_name("sujith")
a.set_mark(39)
a.get_name()
a.get_mark()
# Out:
# sujith
# 39

# %%
class Student:
    def __init__(self):
        self.__name = ""
        self.__marks = 0


    def set_name(self, name):
        self.__name = name


    def get_name(self):
        return self.__name
        print()

    def set_marks(self, marks):
        if marks < 0:
            print("Marks cannot be negative. Please provide a valid value.")
            print()
        else:
            self.__marks = marks


    def get_marks(self):
        return self.__marks
        print()


student = Student()

student.set_name("Anshif")
print("Student Name:", student.get_name())

student.set_marks(95)
print("Student Marks:", student.get_marks())

print()

student.set_marks(-10)
print("Student Marks after invalid attempt:", student.get_marks())
# Out:
# Student Name: Anshif
# Student Marks: 95
#
# Marks cannot be negative. Please provide a valid value.
#
# Student Marks after invalid attempt: 95

# %% [markdown]
# Step1 : Define a Python class Employee with the following private attribute:
#
# __salary to store the employee's salary.A
#
# Step 2 : Implement the following public methods to securely access and modify the salary:
#
# -set_salary(salary) – A method to set the employee's salary (Ensure the salary is a positive value). -get_salary() – A method to retrieve the employee's current salary. -increase_salary(percentage) – A method to increase the salary by a given percentage securely and update the salary value.
#
# Step 3 : Demonstrate the usage of the class by:
#
# -Creating an instance of the Employee class. -Setting the salary to 50000 and printing it using the getter method. -Increasing the salary by 10% and printing the updated salary. -Dont allow negative salary , give warning message

# %%
class employee:
  def __init(self):
     self.salary=0
     self.name=""
  def set_name(self,name):
    self.name=name
  def get_name(self):
    print(f"employeee name:{self.name}")
  def set_salary(self,salary):
    if salary<0:
      print("salary amount is not negative")
    else:
      self.salary=salary
  def get_salary(self):
    print(f"employee {self.name}have {self.salary}")
  def increase_salary(self,percentage):
    self.percentage=percentage
    per_percentage =self.salary*(percentage/100)
    print(f"employee{self.name} updated salary is :{per_percentage + self.salary}")
e=employee()
e.set_name("niya")
e.set_salary(50000)
e.get_name()
e.get_salary()
e.increase_salary(10)
# Out:
# employeee name:niya
# employee niyahave 50000
# employeeniya updated salary is :55000.0

# %% [markdown]
# Create an abstract class Employee with an abstract method calculate_salary(). Implement two subclasses, FullTimeEmployee and PartTimeEmployee, which calculate salaries based on a fixed monthly salary and an hourly rate, respectively. Instantiate both classes and print their salaries.

# %%
class employee:

  @abstractmethod
  def calculate_salary(self):
    pass

class fulltime_employee(employee):

  def __init__(self, salary):
    self.salary=salary

  def calculate_salary(self):
    print(f"salary of full time employee is {self.salary}")

class partime_employee(employee):


  def __init__(self, salary):
    self.salary=salary

  def calculate_salary(self):
    print(f"salary of partime employee is {self.salary/2}")

f=fulltime_employee(10000)
p=partime_employee(10000)

f.calculate_salary()

p.calculate_salary()
# Out:
# salary of full time employee is 10000
# salary of partime employee is 5000.0

# %% [markdown]
# # **iterator-next topic**

# %% [markdown]
# iterator object contains a countable number of values
# it contains__iter__()and __next__() *lists,tuple,dictionaries and sets are all iterable objects**

# %%
mytuple =("apple","banana","cherry")
myit=iter(mytuple)

print(next(myit))
print(next(myit))
mytuple=("banana")
myit=iter(mytuple)
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# apple
# banana
# cherry

# %%
mytuple=("banana")
myit=iter(mytuple)
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# b
# a
# n
# a
# n
# a

# %%
mytuple=("banana")
myit=iter(mytuple)
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# b
# a
# n
# a
# n
# a
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-548398788.py in <cell line: 0>()
#       7 print(next(myit))
#       8 print(next(myit))
# ----> 9 print(next(myit))
#
# StopIteration:

# %%
mytuple =("apple","banana","cherry")
for x in mytuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# # GENERATOR-SIMLIAR TO ITERATOR(TO GET RESULT USE YIELD)

# %%
def greeting():
  print("hiii")
  yield 1
  print("how are you")
  yield 2
  print("done")
  yield 3
messenger = greeting()
print(next(messenger))
print(next(messenger))
print(next(messenger))
# Out:
# hiii
# 1
# how are you
# 2
# done
# 3
